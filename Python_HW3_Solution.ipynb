# %%
import numpy as np 
import math
import scipy

# %% [markdown]
# Problem 3.1

# %%
# JTMS-14
# a3_p1.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy


a1 = int(input())


if(a1 > 0):

  hrs = float(a1/60)
  hrs_int = int(a1/60)

  min = int((hrs - float(hrs_int)) * 60)

  print('%s Minutes = %s Hours and %s Minutes' %(a1, hrs_int ,min ))

else:
  
  print('Input is a invalid Negative Integer')
# Out:
# 100
# 100 Minutes = 1 Hours and 40 Minutes

# %% [markdown]
# Problem 3.2

# %%
# JTMS-14
# a3_p2.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy

#'''

str1 = input()

# This gives error because it treats input as a string. Thus, logical operations 
# are irrelevant.

int1 = input()  

# This is corrected one that prints the string n positive integer times.
#int1 = int(input())  


prod1 = str1 * int1
print(prod1)

#'''

'''


# This incorrect line concatinates the input and treats like two strings.

#int2 = input()
#int3 = input()

# This corrected line adds up and give the sum of value.
int2 = int(input())
int3 = int(input())


add1 = int2 + int3
print(add1)
'''


'''

str2 = input()
float1 = float(input()) # Incorrect line. 

# String can be printed n positive integer times from the function below.

#float1 = int(input()) # Corrected line. 


                                                                                                                             
print(prod2)

'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3ad2a12587da> in <module>
#       7 #'''
#       8
# ----> 9 str1 = input()
#      10
#      11 # This gives error because it treats input as a string. Thus, logical operations
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %% [markdown]
# Problem *3.3*

# %%
# JTMS-14
# a3_p3.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy


int_nr = 428
print('%8d' % int_nr)


float_nr1 = -98.6598894
print('%10.4f' % float_nr1)


character = '$'
print(character)


float_nr2 = 56.486953

print('%.2f' %float_nr2)
# Out:
#      428
#   -98.6599
# $
# 56.49

# %% [markdown]
# **Problem** 3.4

# %%
# JTMS-14
# a3_p4.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy


i1 = int(input())

if( (i1%11) == 0):
  print('The number is divisible by 11')

else:
  print('The number is not divisible by 11')
# Out:
# 11
# The number is divisible by 11

# %% [markdown]
# Problem 3.5

# %%
# JTMS-14
# a3_p5.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy


char = input()

if(ord(char) >= 97 and ord(char) <= 122):
  print('It is lower case')

else:
  print('It is upper case')
# Out:
# K
# It is upper case

# %% [markdown]
# *Problem* 3.6

# %%
# JTMS-14
# a3_p6.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy


n = 0

while n < 11:
  print("n is", n)

  n += 1 # This line was put inside the While loop.

print("That’s it.")
# Out:
# n is 0
# n is 1
# n is 2
# n is 3
# n is 4
# n is 5
# n is 6
# n is 7
# n is 8
# n is 9
# n is 10
# That’s it.

# %% [markdown]
# Problem 3.7

# %%
# JTMS-14
# a3_p7.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy


n = int(input())

while(n < 1):
  print('Enter number greater than or equal to 1')
  n = int(input())

i = 1

while(i <= n):

  print('%i minute = %i seconds' %(i , (i*60)))
  
  i = i + 1
# Out:
# 5
# 1 minute = 60 seconds
# 2 minute = 120 seconds
# 3 minute = 180 seconds
# 4 minute = 240 seconds
# 5 minute = 300 seconds
