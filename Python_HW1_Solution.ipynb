# %%
import numpy as np 
import math
import scipy

# %% [markdown]
# Problem 1.2

# %%
# JTMS-14
# a1_p2.py
# Roshan Shah
# roshah@jacobs-university.de
import numpy as np 
import math
import scipy


print(11)
print(11*3)
print(2**3)
print(13/7)
print(13//7)
#print(9/0)
# Out:
# 11
# 33
# 8
# 1.8571428571428572
# 1

# %% [markdown]
# Problem 1.3

# %%
# JTMS-14
# a1_p3.py
# Roshan Shah
# roshah@jacobs-university.de
import numpy as np 
import math
import scipy

name = "Roshan Shah"
major = "BSc. Physics"

print('%s\n%s' % (name , major))
# Out:
# Roshan Shah
# BSc. Physics

# %% [markdown]
# Problem 1.4

# %%
# JTMS-14
# a1_p4.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy

a,b = 19,3

print('a=' , a)
print('b=' , b)
print('sum=' , a+b)
print('diff=' , a-b)
print('prod=' , a*b )
print('pow=' , a**b)
print('div=' , a/b)
print('int div=' , a//b)
print('remainder=' , a%b)
# Out:
# a= 19
# b= 3
# sum= 22
# diff= 16
# prod= 57
# pow= 6859
# div= 6.333333333333333
# int div= 6
# remainder= 1

# %% [markdown]
# Problem 1.5

# %%
# JTMS-14
# a1_p5.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np 
import math
import scipy

#base = 5
#height = 10

base = float(input("Enter base: "))
height = float(input("Enter height: "))


area = (1/2) * (base) * (height)

print('area=',area)
# Out:
# Enter base: 5
# Enter height: 10
# area= 25.0

# %% [markdown]
# Problem 1.6

# %%
# JTMS-14
# a1_p6.py
# Roshan Shah
# roshah@jacobs-university.de
import numpy as np 
import math
import scipy

#var = 25

var = float(input('Enter a number: '))

sqrt = math.sqrt(var)

print('The square root = ', sqrt)
# Out:
# Enter a number: 25
# The square root =  5.0
