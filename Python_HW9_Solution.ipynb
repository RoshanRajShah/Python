# %%
# JTMS-14
# a9_p1.py
# Roshan Shah
# roshah@jacobs-university.de


"""
File: student.py
Resources to manage a student's name and test scores.
"""

class Student(object):
   """Represents a student."""

   print('Constructor being called')   # HERE PRINT FUNCTION IS ADDED. *****


   def __init__(self, name, number):
      """All scores are initially 0."""
      self._name = name
      self._scores = []
      for count in range(number):
         self._scores.append(0)

   def getName(self):
      """Returns the student's name."""
      return self._name
  
   def setScore(self, i, score):
      """Resets the ith score, counting from 1."""
      self._scores[i - 1] = score

   def getScore(self, i):
      """Returns the ith score, counting from 1."""
      return self._scores[i - 1]
   
   def getAverage(self):
      """Returns the average score."""
      return sum(self._scores) / len(self._scores)
    
   def getHighScore(self):
      """Returns the highest score."""
      return max(self._scores)
 
   def __str__(self):
      """Returns the string representation of the student."""
      return "Name: " + self._name  + "\nScores: " + \
             " ".join(map(str, self._scores))


s1 = Student('Jenny',2)
s2 = Student('Steve',2)
s3 = Student('Celine',2)

s1.setScore(1, 95)
s1.setScore(2, 90)

s2.setScore(1, 95)
s2.setScore(2, 90)

s3.setScore(1, 95)
s3.setScore(2, 90)

print(s1)
print(s2)
print(s3)
# Out:
# Constructor being called
# Name: Jenny
# Scores: 95 90
# Name: Steve
# Scores: 95 90
# Name: Celine
# Scores: 95 90

# %%
# JTMS-14
# a9_p2.py
# Roshan Shah
# roshah@jacobs-university.de


"""
File: die.py

This module defines the Die class.
"""

from random import randint

class Die(object):
    """This class represents a six-sided die."""

    def __init__(self):
        """The initial face of the die."""
        self._value = 1

    def roll(self):
        """Resets the die's value to a random number 
        between 1 and 6."""
        self._value = randint(1, 6)

    def getValue(self):
        return self._value

    def __str__(self):
        return str(self._value)

# %%
# JTMS-14
# a9_p2.py
# Roshan Shah
# roshah@jacobs-university.de


"""
File: craps.py

This module studies and plays the game of craps.
"""

from die import Die

class Player(object):

    def __init__(self):
        """Has a pair of dice and an empty rolls list."""
        self._die1 = Die()
        self._die2 = Die()
        self._rolls = []

    def __str__(self):
        """Returns a string representation of the list of rolls."""
        result = ""
        for (v1, v2) in self._rolls:
            result = result + str((v1, v2)) + " " +\
                     str(v1 + v2) + "\n"
        return result

    def getNumberOfRolls(self):
        """Returns the number of the rolls."""
        return len(self._rolls)

    def play(self):
        """Plays a game, saves the rolls for that game, 
        and returns True for a win and False for a loss."""
        self._rolls = []
        self._die1.roll()
        self._die2.roll()
        (v1, v2) = (self._die1.getValue(),
                    self._die2.getValue())
        self._rolls.append((v1, v2))
        initialSum = v1 + v2
        if initialSum in (2, 3, 12):
            return False
        elif initialSum in (7, 11):
            return True
        while (True):
            self._die1.roll()
            self._die2.roll()
            (v1, v2) = (self._die1.getValue(),
                        self._die2.getValue())
            self._rolls.append((v1, v2))
            sum = v1 + v2
            if sum == 7:
                return False
            elif sum == initialSum:
                return True

def playOneGame():
    """Plays a single game and prints the results."""
    player = Player()
    youWin = player.play()
    print(player)
    if youWin:
        print("You win!")
    else:
        print("You lose!")

def playManyGames():
    """Plays a number of games and prints statistics."""
    number = int(input("Enter the number of games: "))
    wins = 0
    losses = 0
    winRolls = 0
    lossRolls = 0
    player = Player()
    for count in range(number):
        hasWon = player.play()
        rolls = player.getNumberOfRolls()
        if hasWon:
            wins += 1
            winRolls += rolls
        else:
            losses += 1
            lossRolls += rolls
            
    print("The total number of wins is", wins)
    print("The total number of losses is", losses)
    print("The average number of rolls per win is {:0.2f}"\
          .format(winRolls / wins))
    print("The average number of rolls per loss is {:0.2f}"\
          .format(lossRolls / losses))
    print("The winning percentage is {:0.3f}".format(wins / number))

# %%
# JTMS-14
# a9_p2.py
# Roshan Shah
# roshah@jacobs-university.de


from craps import Player
from craps import playOneGame
from craps import playManyGames


a1 = Player()

a2 = (a1.getNumberOfRolls())
print(a2)

a1.play()

playOneGame()
playManyGames()
# Out:
# 0
# (3, 6) 9
# (2, 4) 6
# (5, 6) 11
# (3, 2) 5
# (2, 1) 3
# (4, 5) 9
#
# You win!
# Enter the number of games: 5
# The total number of wins is 4
# The total number of losses is 1
# The average number of rolls per win is 3.00
# The average number of rolls per loss is 1.00
# The winning percentage is 0.800

# %%
# JTMS-14
# a9_p3.py
# Roshan Shah
# roshah@jacobs-university.de



"""
File: rational.py
Resources to manipulate rational numbers.
"""

class Rational(object):
    """Represents a rational number."""

    def __init__(self, numer, denom):
        """Constructor creates a number with the given numerator
        and denominator and reduces it to lowest terms."""
        self._numer = numer
        self._denom = denom
        self._reduce()

    def numerator(self):
        """Returns the numerator."""
        return self._numer
  
    def denominator(self):
        """Returns the denominator."""
        return self._denom
   
    def __str__(self):
        """Returns the string representation of the number."""
        return str(self._numer) + "/" + str(self._denom)

    def _reduce(self):
        """Helper to reduce the number to lowest terms."""
        divisor = self._gcd(self._numer, self._denom)
        self._numer = self._numer // divisor
        self._denom = self._denom // divisor

    def _gcd(self, a, b):
        """Euclid's algorithm for greatest common divisor."""
        a = abs(a)
        b = abs(b)
        (a, b) = (max(a, b), min(a, b))
        while b > 0:
            (a, b) = (b, a % b)
        return a

    # Methods for arithmetic and comparisons go here

    def __add__(self, other):
        """Returns the sum of the numbers."""
        newNumer = self._numer * other._denom + \
                   other._numer * self._denom
        newDenom = self._denom * other._denom
        return Rational(newNumer, newDenom)

    def __lt__(self, other):
        """Returns self < other."""
        extremes = self._numer * other._denom
        means = other._numer * self._denom
        return extremes < means

    def __eq__(self, other):
        """Tests self and other for equality."""
        if self is other: 
            return True
        elif type(self) != type(other):
            return False
        else:
            return self._numer == other._numer and \
                   self._denom == other._denom

# %%
# JTMS-14
# a9_p3.py
# Roshan Shah
# roshah@jacobs-university.de

# test_rational.py

from rational import Rational

n1 = Rational(1,2)
n2 = Rational(1,8)

Sum = n1 + n2

print(Sum)
# Out:
# 5/8

# %%
# JTMS-14
# a9_p4.py
# Roshan Shah
# roshah@jacobs-university.de

# test_rational.py

from rational import Rational

print('Enter Numerator and Denominator and again.')

k11,k12 = int(input()),int(input())  
k21,k22 = int(input()),int(input())

n1 = Rational(k11,k12)
n2 = Rational(k21,k22)

# Numerators

p1 = n1.numerator()
p2 = n2.numerator()

print('The Numerators are: %s and %s' %(p1,p2))

# Denominators

p3 = n1.denominator()
p4 = n2.denominator()

print('The Denominators are: %s and %s' %(p3,p4))

Sum = n1 + n2

print(Sum)
# Out:
# Enter Numerator and Denominator and again.
# 1
# 2
# 1
# 5
# The Numerators are: 1 and 1
# The Denominators are: 2 and 5
# 7/10

# %%
# JTMS-14
# a9_p5.py
# Roshan Shah
# roshah@jacobs-university.de


"""
File: student.py
Resources to manage a student's name and test scores.
"""

class Student(object):
   """Represents a student."""

   print('Constructor being called')   # HERE PRINT FUNCTION IS ADDED. *****


   def __init__(self, name, number):
      """All scores are initially 0."""
      self._name = name
      self._scores = []
      for count in range(number):
         self._scores.append(0)

   def getName(self):
      """Returns the student's name."""
      return self._name
  
   def setScore(self, i, score):
      """Resets the ith score, counting from 1."""
      self._scores[i - 1] = score

   def setName(self,name):
      self._name = name
      #return self._name

   def getScore(self, i):
      """Returns the ith score, counting from 1."""
      return self._scores[i - 1]
   
   def getAverage(self):
      """Returns the average score."""
      return sum(self._scores) / len(self._scores)
    
   def getHighScore(self):
      """Returns the highest score."""
      return max(self._scores)
 
   def __str__(self):
      """Returns the string representation of the student."""
      return "Name: " + self._name  + "\nScores: " + \
             " ".join(map(str, self._scores))
# Out:
# Constructor being called

# %%
# JTMS-14
# a9_p5.py
# Roshan Shah
# roshah@jacobs-university.de


from student import Student

s1 = Student('John',2)

s1.setScore(1, 95)
s1.setScore(2, 50)

print(s1)

s1.setName('Jack')

print(s1)
# Out:
# Name: John
# Scores: 95 50
# Name: Jack
# Scores: 95 50

# %%
# JTMS-14
# a9_p6.py
# Roshan Shah
# roshah@jacobs-university.de


"""
File: student.py
Resources to manage a student's name and test scores.
"""

class Student(object):
   """Represents a student."""



   def __init__(self, name, number):
      """All scores are initially 0."""
      self._name = name
      self._scores = []

      for count in range(number):
         self._scores.append(0)

   def getName(self):
      """Returns the student's name."""
      return self._name
  
   def setScore(self, i, score):
      """Resets the ith score, counting from 1."""
      self._scores[i - 1] = score

   def setAge(self, age):
      """Resets the i_th score, counting from 1."""
      self._ages = age

   def getAge(self):
      """Returns the i_th score, counting from 1."""
      return self._ages



   def getScore(self, i):
      """Returns the ith score, counting from 1."""
      return self._scores[i - 1]
   
   def getAverage(self):
      """Returns the average score."""
      return sum(self._scores) / len(self._scores)
    
   def getHighScore(self):
      """Returns the highest score."""
      return max(self._scores)
  
   def __str__(self):
      """Returns the string representation of the student."""

      return "Name: " + self._name  + "\nScores: " + \
         " ".join(map(str, self._scores)) + "\nAge: " + (str(self._ages))




s1 = Student('John',2)

s1.setScore(1, 95)
s1.setScore(2, 50)
s1.setAge(31)

print(s1)
# Out:
# Name: John
# Scores: 95 50
# Age: 31

# %%
# JTMS-14
# a9_p6.py
# Roshan Shah
# roshah@jacobs-university.de


from student import Student

s1 = Student('John',2)

s1.setScore(1, 95)
s1.setScore(2, 50)
s1.setAge(31)

print(s1)

# %%
# JTMS-14
# a9_p7.py
# Roshan Shah
# roshah@jacobs-university.de


"""
File: article.py
Resources to manage a student's name and test scores.
"""

class Article(object):
   """Represents a student."""



   def __init__(self,name):
      """All scores are initially 0."""
      self._name = name


   def getName(self):
      """Returns the student's name."""
      return self._name
   


   def setWeight(self, weight):
      """Resets the i_th score, counting from 1."""
      self._weights = weight

   def getWeight(self):
      """Returns the i_th score, counting from 1."""
      return self._weights
  

   
   def setColour(self, color):
      """Resets the i_th score, counting from 1."""
      self._colors = color

   def getColour(self):
      """Returns the i_th score, counting from 1."""
      return self._colors




   def setOrigin(self, origin):
      """Resets the i_th score, counting from 1."""
      self._origins = origin

   def getOrigin(self):
      """Returns the i_th score, counting from 1."""
      return self._origins






   def __str__(self):
      """Returns the string representation of the student."""

      return "Name: " + self._name  + "\nWeight: " + \
         (str(self._weights)) + "\nColour: " + ((self._colors)) + \
            "\nOrigin: " + ((self._origins))
# Out:
# Enter n: 3
# Enter Name , Weight , Colour and Country of Origin
# a
# 4
# a
# a
# Name: a
# Weight: 4
# Colour: a
# Origin: a
# Enter Name , Weight , Colour and Country of Origin
# b
# 2
# b
# b
# Name: b
# Weight: 2
# Colour: b
# Origin: b
# Enter Name , Weight , Colour and Country of Origin
# c
# 3
# c
# c
# Name: c
# Weight: 3
# Colour: c
# Origin: c

# %%
# JTMS-14
# a9_p7.py
# Roshan Shah
# roshah@jacobs-university.de


from article import Article

s1 = Article('Mango')
s1.setWeight(95)
s1.setColour('Indian Yellow')
s1.setOrigin('Patna,Bihar')


print(s1)

# %%
# JTMS-14
# a9_p8.py
# Roshan Shah
# roshah@jacobs-university.de


from article import Article

n = int(input('Enter n: '))


for i in range(n):
  print('Enter Name , Weight , Colour and Country of Origin')
  a,b,c,d = input(),int(input()),input(),input()

  s1 = Article(a)
  
  s1.setWeight(b)
  s1.setColour(c)
  s1.setOrigin(d)

  print(s1)
