# %%
# JTMS-14
# a11_p1.py
# Roshan Shah
# roshah@jacobs-university.de

import sys


try:
    f = open('myfile.txt')
    s = f.readline()
    i = int(s.strip())

except OSError as err:
    print("OS error:", err)

except ValueError:
    print("Could not convert data to an integer.")

except Exception as err:
    print(f"Unexpected {err=}, {type(err)=}")
    raise
# Out:
#   File "<fstring>", line 1
#     (err=)
#         ^
# SyntaxError: invalid syntax

# %%
# JTMS-14
# a11_p1.py
# Roshan Shah
# roshah@jacobs-university.de



def file_111(True):

  filename  = input()

  try:
    fileopen = open(filename, "r")

  except FileNotFoundError:
    print("file not found, try again.")
    file111()

# %%
try:
  f1 = open("f1.txt", "w")
  f1.write("This is my test file for exception handling!!")
  
except IOError:
  print("Error: can\'t find file")



else:
   print("Written content in the file successfully")
   f1.close()

f1 = open("f1.txt", "r")
for x in f1:
  print(x)

# %%
def open_file(prompt_str):
    while True:
        filename = input(prompt_str)
        try:
            return open(filename)
        except IOError:
            print(filename + " doesn't exist")


open_file(f1)
# Out:
# <_io.TextIOWrapper name='f1.txt' mode='w' encoding='UTF-8'>f1
# <_io.TextIOWrapper name='f1' mode='r' encoding='UTF-8'>
