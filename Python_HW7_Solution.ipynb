# %%
# JTMS-14
# a7_p1.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np

def word(lst):

  arr1 = lst.split()
  n1 = len(arr1) # size of array, 

  max1 = len(arr1[0])
  pos1 = 0
  arr_obj = ''

  arr2 = []
  pos = []


  for i in range(n1):

    if((len(arr1[i])) < max1):
      continue

    else:
      max1 = len(arr1[i]) # Maximum length of the array element.
      pos1 = i             # Position of that array element.
      arr_obj = arr1[i]   # That array element.

# Checkign for previous words of same Max size.

  for i in range(n1):
    
    if (len(arr1[i]) == max1):

      arr2 = np.append(arr2,arr1[i])
      pos = np.append(pos,i)

    else:
      continue

  return arr2[0],pos[0],arr1,max1


str = input()
lett,pos,arr,n = word(str)

print('Array: \n ',arr)

#print('The longest word in sentence is "%s" in position "%i" of size "%i".' %(lett,pos,n))

print('Longest Word: ', lett)
print('Longest Word Position: ', pos)
# Out:
# ooo pppp wwpppw pppeee
# Array:
#   ['ooo', 'pppp', 'wwpppw', 'pppeee']
# Longest Word:  wwpppw
# Longest Word Position:  2.0

# %%
# JTMS-14
# a7_p2.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np
import string

def translate(list_en):
  dict={'merry':'god','christmas':'jul','and':'och','happy':'got'
  ,'new':'nytt','year':(u'\u00E5r')}


  swed = ''
  
  k = list_en.split()

  for i in k:

    swed = swed + dict[i] + ' '

  return swed

eng = (input()) 
eng = eng.lower()

swedish = translate(eng)
print(swedish)
# Out:
# merry christmas and happy new year
# god jul och got nytt år

# %%
# JTMS-14
# a7_p3.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np
import string


def scal_prod(v,w):


  sum = 0
  k = []

  for i in range(len(v)):

    k = np.append(k,((v[i]) * (w[i])))

  for i in range (len(k)):

    sum = sum + k[i]

  return sum


def max_pos(x):

  max = x[0]
  pos_max = 0

  for i in range(n):

    if(max >= x[i]):
      continue
    else:
      max = x[i]
      pos_max = i

  return max,pos_max


def min_pos(y):

  min = y[0]
  pos_min = 0

  for i in range(n):
    if(min <= y[i]):
      continue

    else:
      min = y[i]
      pos_min = i

  return min,pos_min

#######


n = int(input('Enter n :\n'))

t1 = ()
t2 = ()

res = False

while not res:

  t1 = tuple(input('Enter space-separated for v: ').split())
  t2 = tuple(input('Enter space-separated for w: ').split())
  
  t1 = list(t1)
  t2 = list(t2) 
  
  n1 = len(t1)
  n2 = len(t2)

  if(n1 > n or n2 > n):

    print('More items have been entered than required lenght of n = ',n)
    t1.clear()
    t2.clear()

  else:
    res = True

#print(t1,t2)


t1 = list(t1)
t2 = list(t2)

v = []
w = []

for i in range(n):
  v = np.append(v,float(t1[i]))

for i in range(n):
  w = np.append(w,float(t2[i]))

print(v,w)



scalar_product = scal_prod(v,w)

print('\n')
print('The scalar product:', scalar_product)
print('\n')

maxv,pos_maxv = max_pos(v)
minv,pos_minv = min_pos(v)

print('Tuple = %s\n Maximum = %s\n Maximum Position = %i\n Minimum = %s\n \
Minimum Position = %i\n' %(v,maxv,pos_maxv,minv,pos_minv))

maxw,pos_maxw = max_pos(w)
minw,pos_minw = min_pos(w)

print('Tuple = %s\n Maximum = %s\n Maximum Position = %i\n Minimum = %s\n \
Minimum Position = %i\n' %(w,maxw,pos_maxw,minw,pos_minw))
# Out:
# Enter n :
# 3
# Enter space-separated for v: -1.2 4.5 9.5
# Enter space-separated for w: -1.1 2.1 -6.5
# [-1.2  4.5  9.5] [-1.1  2.1 -6.5]
#
#
# The scalar product: -50.98
#
#
# Tuple = [-1.2  4.5  9.5]
#  Maximum = 9.5
#  Maximum Position = 2
#  Minimum = -1.2
#  Minimum Position = 0
#
# Tuple = [-1.1  2.1 -6.5]
#  Maximum = 2.1
#  Maximum Position = 1
#  Minimum = -6.5
#  Minimum Position = 2

# %%
# JTMS-14
# a7_p4.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np
import string

n = 7 

t1 = []

for i in range(7):
 
  t1 = t1 + (input().split(', '))

print(t1)

t1 = [t for t in t1 if t]

print(t1)

# %%
# JTMS-14
# a7_p5.py
# Roshan Shah
# roshah@jacobs-university.de

import numpy as np
import string

res = False

t1 = []

while not res:
  k = int(input())

  if(k < 0):
    res = True

  else:
    t1.append(k)


print(t1)

t2 = []

n = len(t1)

for i in t1:
    t2 = t1[::-1]
print(t2)
# Out:
# 1
# 2
# 3
# -1
# [1, 2, 3]
# [3, 2, 1]

# %%
# JTMS-14
# a7_p6.py
# Roshan Shah
# roshah@jacobs-university.de

sampleDict = {'Physics': 82, 'Math': 85, 'History': 75,'Management': 70,\
                'Chemistry': 72}


low = min(sampleDict.items(), key=lambda x: x[1]) 
print('The lowest grade is:',low)
# Out:
# The lowest grade is: ('Management', 70)

# %%
# JTMS-14
# a7_p7.py
# Roshan Shah
# roshah@jacobs-university.de

dict = {}

inp = False

while not inp:

  key = input("Enter key : ") 
  value = input("Enter value : ")

  if(key == '' or value == ''):
    inp = True
  else:
    dict[key] = value
    continue
  

print(dict)

print('Enter check Key : ')
k = input()

#value = {i for i in dict if dict[i]== k}

des = False

if k in dict.keys():
  print("Key Exists.",end =" ")
  print("Value =", dict[k])
  
else:
  print("Key Non-Existent.")
# Out:
# Enter key : one
# Enter value : 1
# Enter key : two
# Enter value : 2
# Enter key : three
# Enter value : 3
# Enter key :
# Enter value :
# {'one': '1', 'two': '2', 'three': '3'}
# Enter check Key :
# four
# Key non-existent.

# %%
# JTMS-14
# a7_p8.py
# Roshan Shah
# roshah@jacobs-university.de

stack = []


des = False

while not des:

  lett = input()

 
  if (lett == 's'):
    num = int(input())

    stack.append(num)
    print("Pushing %i" %num)
 
  elif (lett == 'p'):
    if(stack != []):
      print("Popping element %i" %stack.pop())

    else:  
      print('Stack underflow')

  elif (lett == 'e'):
    print("Emptying Stack: ")

    for i in range(len(stack)):
      print("Popping element %i" %stack.pop())
    
  elif (lett == 'q'):
    print("Good Bye !")
    des = True
# Out:
# s
# 5
# Pushing 5
# s
# 7
# Pushing 7
# p
# Popping element 7
# s
# 3
# Pushing 3
# e
# Emptying Stack:
# Popping element 3
# Popping element 5
# p
# Stack underflow
# q
# Good Bye !
